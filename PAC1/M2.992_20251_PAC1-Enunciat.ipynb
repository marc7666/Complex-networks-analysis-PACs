# %% [markdown]
# <div style="width: 100%; clear: both;">
# <div style="float: left; width: 50%;">
# <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg" align="left">
# </div>
# </div>
# <div style="float: right; width: 50%;">
# <p style="margin: 0; padding-top: 22px; text-align:right;">M2.992 · Anàlisi de xarxes complexes</p>
# <p style="margin: 0; text-align:right;">20251 - Màster universitari en Ciència de dades (<i>Data science</i>)</p>
# <p style="margin: 0; text-align:right; padding-button: 100px;">Estudis d'Informàtica, Multimèdia i Telecomunicacions</p>
# </div>
# </div>
# <div style="width: 100%; clear: both;">
# <div style="width:100%;">&nbsp;</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <strong>Nom i cognoms:</strong> Marc Cervera Rosell
# </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong> Avaluació síncrona sobre la PAC.</strong> A més de l’entrega de la PAC, en alguns casos es realitzarà una avaluació síncrona de l’activitat. L’objectiu serà avaluar si l’estudiant comprèn adequadament l’exercici lliurat i ha adquirit les competències necessàries. Si després d’aquesta avaluació es considera que no s’han assolit les competències exigides, la nota es modificarà en conseqüència. <br><br>
# El dia en què es durà a terme aquesta avaluació es publicarà al fòrum de l’assignatura i/o a l’apartat d’Anuncis amb prou antelació. L’avaluació es farà sobre una mostra de l’alumnat que comprendrà entre el 10% i el 35% del total. Aquesta mostra podrà ser aleatòria o dirigida. Un mateix estudiant pot ser avaluat en una, diverses o totes les PAC. Per això, es posaran a disposició dels estudiants diversos slots disponibles i s’avisarà amb 24 hores d’antelació a aquells que hauran de realitzar aquesta avaluació. <br><br>
# L’avaluació de les entregues en període extraordinari es durà a terme durant les últimes setmanes del curs.
# </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong> Fonts bibliogràfiques i ús d’eines d’IA.</strong>
# És necessari que l’estudiant indiqui totes les fonts que ha utilitzat per a l’elaboració dels diferents apartats de la PAC i de quina manera han estat utilitzades. Això inclou qualsevol ús d’eines d’IA generativa o similars, les quals estan permeses. No indicar de manera adequada els recursos utilitzats pot ser considerat plagi i penalitzat amb un suspens (D).
#     </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Figures i representacions gràfiques</strong>
# Les figures han de contenir sempre una etiqueta i ser degudament clares i informatives. Si no es compleixen aquestes condicions, les representacions, quan es demanin, es consideraran completament incorrectes. Algunes guies o exemples sobre com han de ser les figures:
#
# * https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4161295/
# * https://www.quanthub.com/designing-charts-axes-and-value-labels/
#
# Disenyar i representar de forma correcta informació gràfica és una competència transversal que s'ha d'adquirir.
#
# Alguns punts fonamentals:
# * LLegendes clares i informatives incloent-hi les seves unitats.
# * El format de les línies, punts i representacions gràfiques ha de ser tan informatiu i clar com sigui possible.
# * Els textos superposats sobre altres textos o sobre informació gràfica es puntuarà, en general, de manera molt negativa.
# </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong> Puntualitat en el lliurament de la PAC</strong>
# Les PAC lliurades més enllà de la data límit (fins i tot amb minuts de retard) seran avaluades com a entregues realitzades en avaluació extraordinària. Es recomana, per tant, fer el lliurament amb prou antelació per prevenir possibles problemes tècnics d’última hora amb l’exportació del document, problemes de connexió, etc.
# </div>

# %% [markdown]
# # PAC 1: Anàlisi de xarxes
#
# En aquesta pràctica revisarem i aplicarem els coneixements apresos en el **mòdul 1**.
#
# Les **competències** que es treballaran en aquesta activitat són les següents:
#
# 1. Conèixer com es descriuen les xarxes emprant els models de grafs.
# 2. Conèixer els principals mètodes per a l’extracció d’informació i l’emmagatzematge en format de graf.
# 3. Saber quines són les principals característiques de les xarxes reals.
# 4. Entendre les mètriques bàsiques aplicables a grafs i xarxes.
# 5. Conèixer els principals mètodes per a la visualització de xarxes.
# 6. Comprendre els principals models de generació de dades sintètiques.
#
# <u>Consideracions generals</u>:
# - Aquesta prova d’avaluació s’ha de resoldre utilitzant la biblioteca `NetworkX` i les altres biblioteques importades en l’enunciat. L’ús de **qualsevol altra biblioteca s’ha de justificar** dins de la mateixa activitat.
# - Aquesta PEC s’ha de realitzar de manera **estrictament individual**. Qualsevol indici de còpia serà penalitzat amb un suspens (D) per a totes les parts implicades i pot comportar l’avaluació negativa de l’assignatura de manera íntegra.
# - És necessari que l’estudiant indiqui **totes les fonts** que ha utilitzat per a la realització de la PEC. En cas contrari, es considerarà que l’estudiant ha comès plagi, i serà penalitzat amb un suspens (D) i la possible avaluació negativa de l’assignatura de manera íntegra.
#
# <u>Format del lliurament</u>:
#
# - Alguns exercicis poden requerir diversos minuts d’execució, per la qual cosa el lliurament s’ha de fer en **format notebook** i en **format HTML**, on s’hi vegi el codi, els resultats i els comentaris de cada exercici. Es pot exportar el notebook a HTML des del menú File → Download as → HTML.
# - Hi ha un tipus de cel·la especial per incloure text. Aquest tipus de cel·la us serà molt útil per respondre les diferents preguntes teòriques plantejades al llarg de l’activitat. Per canviar el tipus de cel·la, aneu al menú: Cell$\to$ Cell Type $\to$ Markdown.

# %% [markdown]
# ## Càrrega de llibreries
#
#
# A la cel·la següent s’han de carregar totes les biblioteques necessàries per a l’execució de l’activitat. En general, es poden utilitzar altres biblioteques, sempre que s’hi justifiqui el seu ús.

# %%
# !pip install pandas==2.2.3
# !pip install networkx==3.2.1
# !pip install matplotlib
# !pip install numpy==1.26.4
# !pip install itertools
# !pip install pyvis
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement itertools (from versions: none)
# ERROR: No matching distribution found for itertools
# ...

# %%
# Llibreries bàsiques
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import itertools
import pyvis

# Llibreries addicionals (justificar el seu ús)
# %matplotlib inline

# %% [markdown]
# Les versions de les biblioteques que es recomanen per a aquesta activitat són les següents. No és necessari utilitzar exactament aquestes versions, però són amb les quals s’ha provat la solució.
# - NetworkX ver. 3.2.1
# - Pandas ver. 2.2.3
# - Numpy ver. 1.26.4

# %%
# Comprobar les versions
print("NetworkX ver. {}".format(nx.__version__))
print("Pandas ver. {}".format(pd.__version__))
print("Numpy ver. {}".format(np.__version__))
# Out:
# NetworkX ver. 3.2.1
# Pandas ver. 2.2.3
# Numpy ver. 1.26.4

# %% [markdown]
# # PAC 1: 6 graus de separació
# Els 6 graus de separació són un concepte popular i molt estès segons el qual es diu que amb una cadena de 6 amics d’amics es pot arribar a qualsevol altra persona del món, ja sigui el Dalai Lama o Kim Jong-un. Veure: https://en.wikipedia.org/wiki/Six_degrees_of_separation
#
# Aquest concepte també va ser aprofitat pel famós professor de la Universitat de Columbia Duncan J. Watts per titular el seu llibre de divulgació en l’àmbit de les xarxes: *6 graus de separació: La ciència de les xarxes en l’era de l’accés*. Es tracta d’un llibre molt fàcil de llegir i es recomana com a lectura complementària per a aquest curs. A més, s’ha proporcionat juntament amb aquesta PAC el PDF del llibre en la seva versió en anglès, ja que reproduirem algunes parts del mateix.
#
# El més **recomanable abans de realitzar aquesta PAC seria llegir els primers 5 capítols**. En qualsevol cas, com a mínim, s’ha de fer una **lectura completa del capítol 3**, ja que durant els tres primers exercicis d’aquesta PAC es demanarà reproduir algunes parts del mateix. Per al quart exercici, es recomana **llegir de manera completa el capítol 5**.

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Exercici 1: Xarxes de món petit segons el model beta </strong> (3 punts)
# </div>
#
# Es demana:
# * Reproduir la **Figura 3.6: Construction of the beta model** del llibre *6 graus de separació* de Duncan J. Watts. (1,5 punts)
# * Reproduir la **Figura 3.7: Path length and clustering coefficient in the beta model** del llibre *6 graus de separació* de Duncan J. Watts. (1,5 punts)
#
# Notes:
# * Construeix el graf base (figura esquerra de la 3.6) amb la llibreria o funció que necessitis, però després, has d'implementar l'algoritme que explica el llibre per tal d'obtenir el resultat final (figura central o dreta de 3.6).
# * Per obtenir correctament la figura 3.7, no n’hi ha prou només amb variar Beta per obtenir C i L. Per aconseguir un gràfic “suau”, cal que per a cada valor de Beta repeteixis el model X vegades i calculis la mitjana dels resultats obtinguts.
# * Per a la figura 3.7, utilitza un nombre de nodes més gran que en la figura 3.6; almenys 50, 100 o 200 nodes.
# * A la figura 3.7, normalitza els valors obtinguts de path length i clustering perquè estiguin entre 0 i 1. És a dir, pren la llista de valors de clustering i renormalitza’ls de manera que el valor màxim sigui 1 i el mínim sigui 0. Fes el mateix amb els valors de path length.
# * Discuteix al fòrum de l’assignatura els dubtes que puguis tenir i pren les hipòtesis i decisions justificades que consideris, explicant-les clarament.
# * Les figures han de ser el més semblants possible a les mostrades al llibre.

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Solució</strong>
# </div>

# %%
#Construcció del graf base amb la funció watts_strogatz_graph() de la llibreria networkx amb 20 nodes, grau4 i probailitat 0
N = 20 # Nodes del graf base
K = 4 # Grau dels nodes
b = 0 # Prbabilitat beta
x = nx.watts_strogatz_graph(N, K, b) # Bibliografia: [1]
plt.figure()
plt.title("Model  beta amb 20 nodes, grau 4 i probabilitat beta 0")
nx.draw(x, with_labels=True) # Bibliografia: [2] i [6]
plt.show()

# %%
# Procediment per recablejar el graf
import random as rnd # Generacio nombres aleatoris --> generacio de nombres entre 0.0 i 1.0 per saber si recablejar i per eleccio random de nou node
def rewiring_beta_model(x, p):
    nodes = x.nodes() # Tots els nodes del graf base # Bibliografia: [3]
    edges = x.edges() # Totes les arestes del graf base # Bibliografia: [4]
    #p = 0.7 # Probabilitat de recablejar
    """
    Passos rewiring:
    1.- Trobar els K/2 veins a la dreta.
    2.- Si hi ha aresta entre el node que s'esta tractant i el veí i la probabilitat (generada random) < p (probabilitat de rewire) -> rewire
        2.1.- El nou node no pot ser ell mateix
        2.2.- El nou node no pot ser un veí que ja te.
    """
    for node in nodes:
        # Step 1 - Buscar els K/2 veins de la dreta
        rightmost_neighbours = [] # Per guardar els veins
        for vei in range(1, K // 2 + 1): # range(1, 4 // 2 + 1) = [1, 2]
            rightmost_neighbours.append((node + vei) % N) # Calcul dels veins de la dreta
            # Step 2 - Si hi ha aresta entre el node que s'esta tractant i els veins i la probabilitat random < probabilitat de rewire
            for neighbour in rightmost_neighbours:
                if x.has_edge(node, neighbour) and round(rnd.uniform(0.0, 1.0), 1) < p: # Bibliografia: [7] [8] [9] [10]
                    x.remove_edge(node, neighbour) # Descablejar el node i el vei # Bibliografia: [11]
                    new_possible_connections = nodes - x.neighbors(node) - {node} # Els nous possibles nodes son tots - ell mateix - els veins actuals
                    new_node = rnd.choice(list(new_possible_connections)) # Bibliografia: [12]
                    x.add_edge(node, new_node) # Bibliografia [13]
        return x

# %%
rewired = rewiring_beta_model(x, 0.7)
plt.figure(figsize=(15,15)) # Bibliografia: [15]
plt.title("Model beta recablejat")
nx.draw(rewired, with_labels=True)
plt.tight_layout() # Bibliografia: [16]
plt.show()

# %%
# Recreació de la imatge 3.7 del llibre
N = 200
K = 4
times_rep = 100 # Nombre de repeticions per cada beta
beta = [round(i, 2) for i in np.arange(0.0, 1.5, 0.05)] # Probabilitats beta de 0.0 a 1.0 amb un salt de 0.05 # Bibliografia: [17]
path_length = [] # Llista per guardar les L a graficar no normalitzades --> Mitjana de cada beta
clustering_coeff = [] # Llista per guardar les C a graficar no normalitzades --> Mitjana de cada beta
for prob in beta:
    paths_every_beta = []
    clustering_coeff_every_beta = []
    for i in range(times_rep):
        graph = nx.watts_strogatz_graph(N, K, prob) # Generacio del graf base
        paths_every_beta.append(nx.average_shortest_path_length(graph)) # Per cada repeticio ens quedem amb la longitud mitjana del cami mes curt
        # Bibliografia: [18]
        clustering_coeff_every_beta.append(nx.average_clustering(graph)) # Per cada repeticio ens quedem amb el coeficient mitja del graf
        # Bibliografia: [19]
    path_length.append(np.mean(paths_every_beta)) # Bibliografia: [20]
    clustering_coeff.append(np.mean(clustering_coeff_every_beta))
path_length_norm= [] # L normalitzades
# Bibliografia: [21]
for i in range(len(path_length)):
    path_length_norm.append((path_length[i] - min(path_length)) / (max(path_length) - min(path_length)))
clustering_coeff_norm = [] # C normalitzades
for j in range(len(clustering_coeff)):
    clustering_coeff_norm.append((clustering_coeff[j] - min(clustering_coeff)) / (max(clustering_coeff) - min(clustering_coeff)))

# %%
plt.figure()
plt.plot(beta, path_length_norm, color = "red", label="L") # Bibliografia: [14] i [23]
plt.plot(beta, clustering_coeff_norm, color = "green", label="C") # Bibliografia: [14] i [23]
plt.xlabel("Beta")  # Bibliografia: [22]
plt.ylabel("Path length")  # Bibliografia: [22]
plt.title("Path length and clustering coefficient in the beta model")  # Bibliografia: [22]
plt.legend() # Bibliografia: [24]
plt.show()

# %% [markdown]
# **Referències externes:**
#
# [1] --> _watts_strogatz_graph_ [en línia] [consulta: 18 d'octubre de 2025]. Disponible a: [https://networkx.org/documentation/stable/reference/generated/networkx.generators.random_graphs.watts_strogatz_graph.html](https://networkx.org/documentation/stable/reference/generated/networkx.generators.random_graphs.watts_strogatz_graph.html) **--> Documentació de la funció per obtenir el graf base.**
#
# [2] --> _draw_ [en línia] [consulta: 18 d'octubre de 2025]. Disponible a [https://networkx.org/documentation/stable/reference/generated/networkx.drawing.nx_pylab.draw.html](https://networkx.org/documentation/stable/reference/generated/networkx.drawing.nx_pylab.draw.html) **--> Documentació de la funció per a dibuixar el graf base.**
#
# [3] --> _Graph.nodes_ [en línia] [consulta: 18 d'octubre de 2025]. Disponible a: [https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.nodes.html#networkx.Graph.nodes](https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.nodes.html#networkx.Graph.nodes) **--> Documentació de la funció per a obtenir tots els nodes del graf base.**
#
# [4] --> _Graph.edges_ [en línia] [consulta: 18 d'octubre de 2025]. Disponible a: [https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.edges.html#networkx.Graph.edges](https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.edges.html#networkx.Graph.edges) **--> Documentació de la funció per a obtenir totes les arestes del graf base.**
#
# [5] --> _Modelo Watts-Strogatz_ [en línia] [consulta: 18 d'octubre de 2025]. Disponible a: [https://academia-lab.com/enciclopedia/modelo-watts-strogatz/](https://academia-lab.com/enciclopedia/modelo-watts-strogatz/) **--> Web utilizada per obtenir un enunciat més clar de l'algorisme de _rewiring_ i confirmar el funcionament d'aquest després de llegir el capitol 3 del llibre.**
#
# [6] --> _Python | Visualize graphs generated in NetworkX using Matplotlib_ [en línia] [consulta: 18 d'octubre de 2025]. Disponible a: [https://www.geeksforgeeks.org/python/python-visualize-graphs-generated-in-networkx-using-matplotlib/](https://www.geeksforgeeks.org/python/python-visualize-graphs-generated-in-networkx-using-matplotlib/) **--> Web utilitzada per ampliar la informació en el moment de dibuixar el graf.**
#
# [7] --> _MultiDiGraph.has_edge_ [en línia] [consulta: 18 d'octubre de 2025]. Disponible a: [https://networkx.org/documentation/stable/reference/classes/generated/networkx.MultiDiGraph.has_edge.html](https://networkx.org/documentation/stable/reference/classes/generated/networkx.MultiDiGraph.has_edge.html) **--> Documentació de la funció per a saber si existeix una aresta entre dos nodes.**
#
# [8] --> _Python Random uniform() Method_ [en línia] [consulta: 18 d'octubre de 2025]. Disponible a: [https://www.w3schools.com/python/ref_random_uniform.asp](https://www.w3schools.com/python/ref_random_uniform.asp) **--> Documentació de la funció per a generar nombres aleatoris de tipus float.**
#
# [9] --> _Generate Random Float numbers in Python using random() and Uniform()_ [en línia] [consulta: 18 d'octubre de 2025]. Disponible a: [https://pynative.com/python-get-random-float-numbers/](https://pynative.com/python-get-random-float-numbers/) **--> Web utilitzada per cercar informació sobre nombres aleatoris de tipus float.**
#
# [10] --> _random — Generate pseudo-random numbers_ [en línia] [consulta: 18 d'octubre de 2025]. Disponible a: [https://docs.python.org/3/library/random.html#random.uniform](https://docs.python.org/3/library/random.html#random.uniform) **--> Documentació de la llibreria _random_.**
#
# [11] --> _Graph.remove_edge_ [en línia] [consulta: 19 d'octubre de 2025]. Disponible a: [https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.remove_edge.html](https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.remove_edge.html) **--> Documentació de la funció per a eliminar una aresta entre dos nodes.**
#
# [12] --> _Python Random choice() Method_ [en línia] [consulta: 19 d'octubre de 2025]. Disponible a: [https://www.w3schools.com/python/ref_random_choice.asp](https://www.w3schools.com/python/ref_random_choice.asp) **--> Documentació de la funció per a fer una selecció aleatòria d'una seqüència.**
#
# [13] --> _Graph.add_edge_ [en línia] [consulta: 19 d'octubre de 2025]. Disponible a: [https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.add_edge.html](https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.add_edge.html) **--> Documentació de la funció per a afegir una aresta entre dos nodes.**
#
# [14] --> _ChatGPT_ [en línia] [consulta: 19 d'octubre de 2025]. Disponible a: [https://chatgpt.com/](https://chatgpt.com/) **--> Eina d'IA generativa utilitzada per solucionar un error en el calcul de _new_possible_connections_: _TypeError: unsupported operand type(s) for -: 'NodeView' and 'method'_.**
#
# **També utilitzat per solucionar l'error en el moment de calcular _new_node_: _TypeError: 'set' object is not subscriptable_.**
#
# **També utilitzada per saber com posar dues linies en un mateix grafic i quina es la funció per a un gràfic de linies.**
#
# [15] --> _matplotlib.pyplot.figure_ [en línia] [consulta: 19 d'octubre de 2025]. Disponible a: [https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.figure.html](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.figure.html) **--> Documentació de la funció per crear una nova figura. Revisada pel paràmetre figsize.**
#
# [16] --> _Tight layout guide_ [en línia] [consulta: 19 d'octubre de 2025]. Disponible a: [https://matplotlib.org/stable/users/explain/axes/tight_layout_guide.html](https://matplotlib.org/stable/users/explain/axes/tight_layout_guide.html) **--> Documentació de la funció _tight_layout()_ per a ajustar una figura a la mida marcada.**
#
# [17] --> _numpy.arange_ [en línia] [consulta: 20 d'octubre de 2025]. Disponible a: [https://numpy.org/doc/2.3/reference/generated/numpy.arange.html](https://numpy.org/doc/2.3/reference/generated/numpy.arange.html) **--> Documentació de la funció per a crear la llista de betas desde 0.0 a 1.0 amb un salt de 0.05.**
#
# [18] --> _average_shortest_path_length_ [en línia] [consulta: 20 d'octubre de 2025]. Disponible a: [https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.shortest_paths.generic.average_shortest_path_length.html#networkx.algorithms.shortest_paths.generic.average_shortest_path_length](https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.shortest_paths.generic.average_shortest_path_length.html#networkx.algorithms.shortest_paths.generic.average_shortest_path_length) **--> Documentació de la funció per a obtenir la mitjana del camí mes curt d'un graf.**
#
# [19] --> _average_clustering_ [en línia] [consulta: 20 d'octubre de 2025]. Disponible a: [https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.cluster.average_clustering.html#networkx.algorithms.cluster.average_clustering](https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.cluster.average_clustering.html#networkx.algorithms.cluster.average_clustering) **--> Documentació de la funció per a obtenir el coeficient de clustering mitjà d'un graf.**
#
# [20] --> _numpy.mean_ [en línia] [consulta: 20 d'octubre de 2025]. Disponible a: [https://numpy.org/doc/2.2/reference/generated/numpy.mean.html](https://numpy.org/doc/2.2/reference/generated/numpy.mean.html) **--> Documentació de la funció per a la mitjana aritmètica.**
#
# [21] --> _Google Gemini_ [en línia] [consulta: 20 d'octubre de 2025]. Disponible a: [https://gemini.google.com/app?hl=es-ES](https://gemini.google.com/app?hl=es-ES) **--> Eina d'IA generativa utilitzada per obtenir informació sobre tècniques de normalització.**
#
# **També utilitzat per saber si le model de Barabási-Albert permet multiconnexió de nodes y _self-loops_ (Exercici 2).**
#
# [22] --> _Plot line graph from NumPy array_ [en línia] [consulta: 20 d'octubre de 2025]. Disponible a: [https://www.geeksforgeeks.org/python/plot-line-graph-from-numpy-array/](https://www.geeksforgeeks.org/python/plot-line-graph-from-numpy-array/) **--> Web usada per saber com posar noms als eixos i titol al gràfic.**
#
# [23] --> _matplotlib.pyplot.plot_ [en línia] [consulta: 20 d'octubre de 2025]. Disponible a: [https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html) **--> Documentació oficial de la funció per a dibuixar un gràfic de linies. Revisada pels paràmetres _color_ i _label_.**
#
# [24] --> _matplotlib.pyplot.legend_ [en línia] [consulta: 20 d'octubre de 2025]. Disponible a: [https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html) **--> Documentació oficial de la funció per a afegir una llegenda.**

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Exercici 2: Xarxes de món petit segons el model de preferential attachment de Barabási </strong> (3 punts)
# </div>
# Existeixen diversos models de creixement i dinàmica de xarxes. El model de preferential attachment de Barabási també és un model dinàmic molt popular. Pots llegir-ne més a: https://networksciencebook.com/chapter/5#growth
#
#
#
#
# Es demana:
# * Implementa l'algoritme de preferential attachment de Barabási (no utilitzis una llibreria) (0.5p)
# * Representa una figura com la figura 5.3 utilitzant aquest model de creixement de https://networksciencebook.com/chapter/5#growth (1p)
# * Representa la figura 5.4 de https://networksciencebook.com/chapter/5#growth (1.5p)

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Solució</strong>
# </div>

# %%
import random as rnd
# Bibliografia: [26]
# m = Nombre de noves connexions
# final_graph_nodes = Nombre de nodes amb finals --> Condicio per parar l'algorisme
def barabasi_albert_preferential_attachement(graph, m, final_graph_nodes):
    final_graph = graph.copy() # Bibliografia: [35]
    initial_nodes = len(list(graph.nodes()))
    for i in range(initial_nodes, final_graph_nodes):
        node_degrees = dict(final_graph.degree()) # Diciconari {node: grau} # Bibliografia: [27]
        connections_of_new_node = rnd.choices(list(node_degrees.keys()), weights=list(node_degrees.values()), k=m) # Bibliografia: [28] i [29]
        # weights = possibilitat per cada node. k = llarg de la llista reotrn
        final_graph.add_node(len(list(nx.nodes(final_graph)))) # len(list(nx.graph(nodes))) --> Nom nou node = següent nombre de la llista # Bibliografia: [30] i [31]
        for node in connections_of_new_node:
            final_graph.add_edge(node, i)
    return final_graph

# %%
# Graf base per a crear la imatge 5.3
base_graph = nx.Graph()
base_graph.add_nodes_from(range(5))# Bibliografia: [32]
while not nx.is_connected(base_graph): # Bibliografia: [33]
    node1 = rnd.randint(0, 4) # Bibliografia: [34]
    node2 = rnd.randint(0, 4) # Bibliografia: [34]
    base_graph.add_edge(node1, node2)

plt.figure()
nx.draw(base_graph, with_labels=True)
plt.show()

# %%
evolution = [] # Llista per a guardar els diferents grafs. Guardara l'evolucio desde el graf base fins al graf final
evolution.append(base_graph) # El primer es el graf base

for i in range(6, 15):
    #graph_barabasi = base_graph
    graph_barabasi = barabasi_albert_preferential_attachement(base_graph, 3, i)
    evolution.append(graph_barabasi)

# %%
plt.figure() 
fig, ax = plt.subplots(2, 5, figsize=(20,10)) # Bibliografia: [36]
k = 0
for i in range(2):
    for j in range(5):
        nx.draw(evolution[k], with_labels=True, ax=ax[i, j]) # Bibliografia: [2]
        k += 1
plt.show()

# %%
# Construcció imatge 5.4
random_graph = nx.Graph()
random_graph.add_nodes_from(range(5))# Bibliografia: [32]
while not nx.is_connected(random_graph): # Bibliografia: [33]
    node1 = rnd.randint(0, 4) # Bibliografia: [34]
    node2 = rnd.randint(0, 4) # Bibliografia: [34]
    random_graph.add_edge(node1, node2)

m = 5
final_nodes = 10000
final_graph = barabasi_albert_preferential_attachement(random_graph, m, final_nodes)
# --- Trobar probabilitats de cada grau i grafic ----- # Bibliografia: [37]
degrees_mapping = final_graph.degree() # Mapping node: grau # Bibliografia: [38]
degrees_list = list(dict(degrees_mapping).values()) # Llista de graus --> Casos possibles
degrees_cardinality = {} # Mapping grau d'un node: nombre de vegades que existeix el grau en el graf (casos favorables)
for num in degrees_list:
    if num in degrees_cardinality.keys():
        degrees_cardinality[num] += 1
    else:
        degrees_cardinality[num] = 1
possible_cases = len(degrees_list) # Total de casos possibles
probabilities = {} # grau d'un node: probabilitat
for i in degrees_cardinality.keys():
    probabilities[i] = degrees_cardinality[i] / possible_cases

# ----- Log-Binning ----- # Bibliografia: [41] i [42]
max_x = np.log10(max(probabilities.keys())) # Bibliografia: [43]
max_y = np.log10(max(probabilities.values())) # Bibliografia: [43]
max_base = max([max_x, max_y])
min_x = np.log10(min([key for key in probabilities.keys() if key!=0])) # Bibliografia: [43]
bins = np.logspace(min_x, max_base, num=35) # Bibliografia: [44]
keys = np.array(list(probabilities.keys())) # Bibliografia: [45]
vals = np.array(list(probabilities.values())) # Bibliografia: [45]
bin_means_x = (np.histogram(keys, bins, weights=keys)[0] / np.histogram(keys, bins)[0]) # Bibliografia: [46]
bin_means_y = (np.histogram(keys, bins, weights=vals)[0] / np.histogram(keys, bins)[0]) # Bibliografia: [46]

plt.figure(figsize=(15,10))
plt.loglog(probabilities.keys(), probabilities.values(), 'o') # Bibliografia: [37] i [39]
plt.loglog(bin_means_x, bin_means_y, 'x', color='red') # Bibliografia: [47]
plt.ylabel("Pk", fontsize=18) # Bibliografia: [40]
plt.xlabel("k", fontsize=18) # Bibliografia: [40]
plt.show()
# Out:
# C:\Users\mcr99\AppData\Local\Temp\ipykernel_13628\1390366308.py:34: RuntimeWarning: invalid value encountered in divide
#   bin_means_x = (np.histogram(keys, bins, weights=keys)[0] / np.histogram(keys, bins)[0]) # Bibliografia: [46]
# C:\Users\mcr99\AppData\Local\Temp\ipykernel_13628\1390366308.py:35: RuntimeWarning: invalid value encountered in divide
#   bin_means_y = (np.histogram(keys, bins, weights=vals)[0] / np.histogram(keys, bins)[0]) # Bibliografia: [46]

# %% [markdown]
# **Referències externes**
#
# [25] --> _complete_graph_ [en línia] [consulta: 20 d'octubre de 2025]. Disponible a: [https://networkx.org/documentation/stable/reference/generated/networkx.generators.classic.complete_graph.html](https://networkx.org/documentation/stable/reference/generated/networkx.generators.classic.complete_graph.html) **--> Documentació de la funció per a crear un graf.**
#
# [26] --> _Modelo Barabási–Albert_ [en línia] [consulta: 20 d'octubre de 2025]. Disponible a: [https://es.wikipedia.org/wiki/Modelo_Barab%C3%A1si%E2%80%93Albert](https://es.wikipedia.org/wiki/Modelo_Barab%C3%A1si%E2%80%93Albert) **--> Utilitzat per obtenir un enunciat formal de l'algorisme.**
#
# [27] --> _Graph.degree_ [en línia] [consulta: 20 d'octubre de 2025]. Disponible a: [https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.degree.html](https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.degree.html) **--> Documentació de la funció per a obtenir el grau dels nodes d'un graf.**
#
# [28] --> _Python Random choices() Method_ [en línia] [consulta: 20 d'octubre de 2025]. Disponible a: [https://www.w3schools.com/python/ref_random_choices.asp](https://www.w3schools.com/python/ref_random_choices.asp) **--> Documentació de la funció per a escollir un nombre k d'elements d'una seqüència.**
#
# [29] --> _Python - random.choices() method_ [en línia] [consulta: 20 d'octubre de 2025]. Disponible a: [https://www.geeksforgeeks.org/python/random-choices-method-in-python/](https://www.geeksforgeeks.org/python/random-choices-method-in-python/) **--> Documentació de la funció per a escollir un nombre k d'elements d'una seqüència.**
#
# [30] --> _Creating a graph_ [en línia] [consulta: 20 d'octubre de 2025]. Disponible a: [https://pelegm-networkx.readthedocs.io/en/latest/tutorial/tutorial.html](https://pelegm-networkx.readthedocs.io/en/latest/tutorial/tutorial.html) **--> Tutorial per a crear un graf.**
#
# [31] --> _Graph.add_node_ [en línia] [consulta: 20 d'octubre de 2025]. Disponible a: [https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.add_node.html](https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.add_node.html) **--> Documentació de la funció per a afegir un node a un graf.**
#
# [32] --> _Graph.add_nodes_from_ [en línia] [consulta: 21 d'octubre de 2025]. Disponible a: [https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.add_nodes_from.html](https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.add_nodes_from.html) **--> Documentació de la funció per a afegir múltiples nodes a un graf.**
#
# [33] --> _is_connected_ [en línia] [consulta: 21 d'octubre de 2025]. Disponible a: [https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.components.is_connected.html](https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.components.is_connected.html) **--> Documentació de la funció per saber si un graf es connex.**
#
# [34] --> _Python Random randint() Method_ [en línia] [consulta: 21 d'octubre de 2025]. Disponible a: [https://www.w3schools.com/python/ref_random_randint.asp](https://www.w3schools.com/python/ref_random_randint.asp) **--> Documentació de la funció per a generar enters de manera aleatòria.**
#
# [35] --> _Graph.copy_ [en línia] [consulta: 21 d'octubre de 2025]. Disponible a: [https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.copy.html](https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.copy.html) **--> Documentació de la funció per a crear una còpia d'un graf.**
#
# [36] --> _Create multiple subplots using plt.subplots_ [en línia] [consulta: 21 d'octubre de 2025]. Disponible a: [https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html](https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html) **--> Documentació de la funció per a crear una figura amb un nombre x de subfigures.**
#
# [37] --> _Plotting the degree distribution of a graph using nx.degree_histogram_ [en línia] [consulta: 21 d'octubre de 2025]. Disponible a: [https://stackoverflow.com/questions/53958700/plotting-the-degree-distribution-of-a-graph-using-nx-degree-histogram](https://stackoverflow.com/questions/53958700/plotting-the-degree-distribution-of-a-graph-using-nx-degree-histogram) **--> Conversa de StackOverflow usada per obtenir una idea de com crear el gràfic de la distribució de graus.**
#
# [38] --> _Graph.degree_ [en línia] [consulta: 21 d'octubre de 2025]. Disponible a: [https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.degree.html](https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.degree.html) **--> Documentació de la funció per a obtenir un DegreeView que fa un mapping de cada node amb el seu grau.**
#
# [39] --> _matplotlib.pyplot.loglog_ [en línia] [consulta: 21 d'octubre de 2025]. Disponible a: [https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.loglog.html](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.loglog.html) **--> Documentació de la funció per a crear un grafic amb escala logaritmica.**
#
# [40] --> _How do I set the figure title and axes labels font size?_ [en línia] [consulta: 21 d'octubre de 2025]. Disponible a: [https://stackoverflow.com/questions/12444716/how-do-i-set-the-figure-title-and-axes-labels-font-size](https://stackoverflow.com/questions/12444716/how-do-i-set-the-figure-title-and-axes-labels-font-size) **--> Conversa de StackOverflow usada per saber com modificar les etiquetes i la mida de la lletra dels eixos x i y.**
#
# [41] --> _Plotting log-binned network degree distributions_ [en línia] [consulta: 21 d'octubre de 2025]. Disponible a: [https://stackoverflow.com/questions/16489655/plotting-log-binned-network-degree-distributions](https://stackoverflow.com/questions/16489655/plotting-log-binned-network-degree-distributions) **--> Conversa de StackOverflow usada per trobar una mostra de com codificar el log-binning.**
#
# [42] --> _Log binning distribution using python networkx_ [en línia] [consulta: 21 d'octubre de 2025]. Disponible a: [https://stackoverflow.com/questions/65026937/log-binning-distribution-using-python-networkx](https://stackoverflow.com/questions/65026937/log-binning-distribution-using-python-networkx) **--> Conversa de StackOverflow usada per trobar una mostra de com codificar el log-binning.**
#
# [43] --> _numpy.log10_ [en línia] [consulta: 21 d'octubre de 2025]. Disponible a: [https://numpy.org/doc/2.1/reference/generated/numpy.log10.html](https://numpy.org/doc/2.1/reference/generated/numpy.log10.html) **--> Documentació de la funció per a obtenir el logaritme en base 10 d'un element.**
#
# [44] --> _numpy.logspace_ [en línia] [consulta: 21 d'octubre de 2025]. Disponible a: [https://numpy.org/doc/2.0/reference/generated/numpy.logspace.html](https://numpy.org/doc/2.0/reference/generated/numpy.logspace.html) **--> Documentació de la funció per a crear nombres separats de manera uniforme en escala logarítmica.**
#
# [45] --> _numpy.array_ [en línia] [consulta: 21 d'octubre de 2025]. Disponible a: [https://numpy.org/doc/stable/reference/generated/numpy.array.html](https://numpy.org/doc/stable/reference/generated/numpy.array.html) **--> Documentació de la funció per crear una array.**
#
# [46] --> _NumPy.histogram() Method in Python_ [en línia] [consulta: 21 d'octubre de 2025]. Disponible a: [https://www.geeksforgeeks.org/python/numpy-histogram-method-in-python/](https://www.geeksforgeeks.org/python/numpy-histogram-method-in-python/) **--> Documentació de la funció per crear un histograma.**
#
# [47] --> _Log-Log Plots in Matplotlib_ [en línia] [consulta: 21 d'octubre de 2025]. Disponible a: [https://pythonguides.com/matplotlib-log-log-plot/](https://pythonguides.com/matplotlib-log-log-plot/) **--> Web que ensenya com utilitzar els _loglog plots_. Revisat per saber com cambiar el color de una marca.**

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Exercici 3: Valors de xarxes reals </strong> (3 punts)
# </div>
#
# Es demana:
# * Reproduir la **taula 3.2: Statistics of small world networks** del llibre *6 graus de separació* de Duncan J. Watts. Per fer-ho, cal obtenir les dades de manera lliure. Adjunteu a l'entrega l'arxiu de dades emprat per tal de poder reproduir la solució. (2,25 punts)
#     * No cal calcular ni incloure la fila de "movie actors" d’aquesta taula.
# * (a) Discutir els resultats obtinguts en un màxim de dues línies, comparant-los amb el que es menciona al capítol 3 del llibre i, a més, (b) respondre sobre cadascuna de les xarxes anteriors el següent: (0,25 punts)
#     * Es tracta d’un graf dirigit o no dirigit? Per què? (màxim dues línies)
#     * Es tracta d’un graf ponderat o no ponderat? Per què? (màxim dues línies)
# * Realitzar una representació d’alguna de les xarxes anteriorment calculades (power grid o C. elegans). Aquesta representació ha d’estar *treballada*, i es recomana utilitzar alguna biblioteca de representacions dinàmiques de xarxes com pyvis, plotly, bokeh, etc. (0,5 punts)

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Solució</strong>
# </div>

# %%
len(list(nx.nodes(graph)))
# Out:
# 10

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Exercici 4: El món des de la Novena Avinguda</strong> (1 punt)
# </div>

# %% [markdown]
# Al capítol 5 es parla d’una figura 5.4 que, per algun motiu, no apareix correctament al PDF de la versió del llibre que es lliura. Aquesta figura és la següent: https://en.wikipedia.org/wiki/View_of_the_World_from_9th_Avenue
#
# Explica amb les teves pròpies paraules què representa aquesta imatge des del punt de vista de la ciència de les xarxes. Aquesta informació està explicada al llibre proporcionat, però es demana que l’estudiant demostri que l’ha comprès, explicant-la amb les seves pròpies paraules i incloent algun exemple. L’explicació es pot reforçar amb alguna imatge nova, article científic, exemples, resultats, etc.
#
# Se recomana llegir el capítol 5 per respondre a aquesta pregunta.

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Solució </strong>
# </div>
