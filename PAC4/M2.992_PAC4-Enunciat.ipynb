# %% [markdown]
# <div style="width: 100%; clear: both;">
# <div style="float: left; width: 50%;">
# <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg" align="left">
# </div>
# </div>
# <div style="float: right; width: 50%;">
# <p style="margin: 0; padding-top: 22px; text-align:right;">M2.992 · Anàlisi de xarxes complexes</p>
# <p style="margin: 0; text-align:right;">20251 - Màster universitari en Ciència de dades (<i>Data science</i>)</p>
# <p style="margin: 0; text-align:right; padding-button: 100px;">Estudis d'Informàtica, Multimèdia i Telecomunicacions</p>
# </div>
# </div>
# <div style="width: 100%; clear: both;">
# <div style="width:100%;">&nbsp;</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <strong>Nom i cognoms:</strong> Marc Cervera Rosell
# </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong>Recordatori: Verificació d'autoria mitjançant entrevista de contrast </strong>
# Aquesta activitat està subjecta a la verificació de l'autoria, la qual pot incloure entrevistes de contrast, tal com es descriu en el pla docent de l'assignatura. En cas que el professorat ho consideri necessari, es podrà convocar l'estudiant per realitzar una entrevista amb l'objectiu de comprovar la correspondència entre el contingut presentat i els coneixements adquirits, així com l'autoria independent de l'activitat.
# Trobareu més informació en el pla docent de l'assignatura.. <br><br>
# </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
#     <strong> Fonts bibliogràfiques i ús d’eines d’IA.</strong>
# És necessari que l’estudiant indiqui totes les fonts que ha utilitzat per a l’elaboració dels diferents apartats de la PAC i de quina manera han estat utilitzades. Això inclou qualsevol ús d’eines d’IA generativa o similars, les quals estan permeses. No indicar de manera adequada els recursos utilitzats pot ser considerat plagi i penalitzat amb un suspens (D).
#     </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong>Figures i representacions gràfiques</strong>
# Les figures han de contenir sempre una etiqueta i ser degudament clares i informatives. Si no es compleixen aquestes condicions, les representacions, quan es demanin, es consideraran completament incorrectes. Algunes guies o exemples sobre com han de ser les figures:
#
# * https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4161295/
# * https://www.quanthub.com/designing-charts-axes-and-value-labels/
#
# Disenyar i representar de forma correcta informació gràfica és una competència transversal que s'ha d'adquirir.
#
# Alguns punts fonamentals:
# * LLegendes clares i informatives incloent-hi les seves unitats.
# * El format de les línies, punts i representacions gràfiques ha de ser tan informatiu i clar com sigui possible.
# * Els textos superposats sobre altres textos o sobre informació gràfica es puntuarà, en general, de manera molt negativa.
# </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;">
# <strong> Puntualitat en el lliurament de la PAC</strong>
# Les PAC lliurades més enllà de la data límit (fins i tot amb minuts de retard) seran avaluades com a entregues realitzades en avaluació extraordinària. Es recomana, per tant, fer el lliurament amb prou antelació per prevenir possibles problemes tècnics d’última hora amb l’exportació del document, problemes de connexió, etc.
# </div>

# %% [markdown]
# # PAC 4: Aprenentatge automàtic en grafs
#
#
# En aquesta pràctica es posaran en pràctica els coneixements adquirits al mòdul 5 i, a més, servirà per repassar alguns conceptes apareguts anteriorment. També s’hi introdueixen conceptes transversals relacionats amb el *Deep Learning*.
#
# Les **competències** que es treballaran en aquesta activitat són les següents:
#
# 1. Comprendre la problemàtica i saber aplicar les tècniques més rellevants en un escenari de predicció o classificació sobre grafs.
# 2. Saber dissenyar i aplicar diferents algorismes relacionats amb les *Graph Neural Networks*.
#
# I els **resultats d’aprenentatge** esperats són:
#
# 1. Conèixer tècniques modernes de xarxes neuronals sobre grafs.
# 2. Conèixer el funcionament i els principals models de les GNNs.
# 3. Saber interpretar les mètriques d’avaluació de les GNNs.
#
# <u>Consideracions generals</u>:
#
# * Aquesta prova d’avaluació s’ha de resoldre utilitzant la llibreria `NetworkX`, `torch_geometric`, `torch` i altres llibreries importades a l’enunciat. L’ús de qualsevol **altra llibreria s’ha de justificar** en la mateixa activitat.
# * Aquesta PAC s’ha de realitzar de manera **estrictament individual**. Qualsevol indici de còpia serà penalitzat amb un suspens (D) per a totes les parts implicades i amb la possible avaluació negativa de l’assignatura en la seva totalitat.
# * És necessari que l’estudiant indiqui **totes les fonts** que ha utilitzat per a la realització de la PAC. En cas contrari, es considerarà que l’estudiant ha comès plagi, i serà penalitzat amb un suspens (D) i la possible avaluació negativa de l’assignatura en la seva totalitat.
#
# <u>Format del lliurament</u>:
#
# * Alguns exercicis poden suposar diversos minuts d’execució; per tant, el lliurament s’ha de fer en **format notebook** i en **format HTML**, on es vegi el codi, els resultats i els comentaris de cada exercici. Es pot exportar el notebook a HTML des del menú *File* $\to$ *Download as* $\to$ *HTML*.
# * També s’haurà de lliurar el vídeo que es demana en un dels enunciats.
# * Existeix un tipus de cel·la especial per allotjar text. Aquest tipus de cel·la us serà molt útil per respondre les diferents preguntes teòriques plantejades al llarg de l’activitat. Per canviar el tipus de cel·la a aquest, al menú: *Cell* $\to$ *Cell Type* $\to$ *Markdown*.

# %% [markdown]
# ## Càrrega de llibreries
#
# En la següent cel·la s’han de carregar totes les llibreries necessàries per a l’execució de l’activitat.
# Cal justificar l’ús de qualsevol llibreria addicional que no formi part del conjunt bàsic requerit.

# %%
# !pip install torch

# %%
# !pip install torch_geometric

# %%
import numpy as np
import networkx as nx
import pandas as pd
import tqdm
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv, SAGEConv, GINConv, global_mean_pool
from torch_geometric.loader import DataLoader
from torch_geometric.data import Dataset, Data
from torch_geometric.utils import to_networkx
import random
import copy
import matplotlib.pyplot as plt

# %% [markdown]
# ## Introducció. Graph neural networks aplicades a la química i la bioinformàtica.
#
#
# Si et preguntes per a què serveixen les *graph neural networks*, una resposta senzilla i directa és: per guanyar el **Premi Nobel de Química de 2024**.
#
# * [https://rseq.org/david-baker-demis-hassabis-y-john-m-jumper-premio-nobel-de-quimica-2024](https://rseq.org/david-baker-demis-hassabis-y-john-m-jumper-premio-nobel-de-quimica-2024)
#
# Això ho van aconseguir resolent, mitjançant els models **AlphaFold** i **AlphaFold2**, un dels problemes més inabordables de la química fins al moment: predir el comportament espacial i l’estructura de les cadenes químiques a partir dels seus subcomponents. Això obre la porta a accelerar el disseny de fàrmacs específics com mai abans. Per conèixer què són els models AlphaFold (actualment en la seva tercera versió), et recomano veure el vídeo introductori següent:
#
# * [https://www.youtube.com/watch?v=gg7WjuFs8F4&t](https://www.youtube.com/watch?v=gg7WjuFs8F4&t)
#
# I per conèixer una mica més un dels guardonats, a continuació tens una entrevista que li han fet fa poc temps:
#
# * [https://www.youtube.com/watch?v=-pGs0btGmgY](https://www.youtube.com/watch?v=-pGs0btGmgY)
#
# En aquesta PAC ens submergim en el món de la bioinformàtica de la mà de les *graph neural networks*.

# %% [markdown]
# ## PAC
# En aquesta ocasió anem a calcular alguns dels resultats que es mostren en l’article **SICGNN: structurally informed convolutional graph neural networks for protein classification** https://iopscience.iop.org/article/10.1088/2632-2153/ad979b#mlstad979bs4

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;"> <strong>Exercici 0: Entendre graph neural networks recents: GAT, GIN i GraphSage (1.5 punts)</strong> </div>
#
# <div style="background-color: #AAF7FF; border-color: #7A9DBF; border-left: 5px solid #7C9DBF; padding: 0.0em;"> <strong>Atenció: Exercici indispensable per aprovar la PAC</strong> </div>
#
#
# * Es recomana realitzar aquest apartat al final de la PAC, ja que durant l’exercici s’espera que aprengueu en profunditat aquests algorismes. Tanmateix, s’ha volgut anunciar al principi de la PAC perquè no es passi per alt aquest apartat fonamental. **Sense aquest apartat degudament completat i aprovat, no es corregirà la PAC.**
#
# * **Instruccions:**
#
#   * Elabora un **vídeo d’1 minut com a màxim** en què expliquis les principals característiques i diferències entre els algorismes **GAT**, **GraphSAGE** i **GIN**.
#
#     * GAT: [https://arxiv.org/pdf/1710.10903](https://arxiv.org/pdf/1710.10903)
#     * GraphSAGE: [https://arxiv.org/pdf/1706.02216](https://arxiv.org/pdf/1706.02216)
#     * GIN: [https://arxiv.org/pdf/1810.00826v3](https://arxiv.org/pdf/1810.00826v3)
#   * T’has de recolzar en una o diverses diapositives o en elements interactius.
#   * L’estudiant ha de ser clarament visible al vídeo juntament amb la diapositiva.
#   * Les diapositives no poden contenir text. Únicament informació gràfica i paraules soltes per donar suport a aquesta informació.
#   * Està prohibit llegir. Això comportaria una qualificació negativa.
#   * L’àudio i el vídeo han de ser clars i d’una qualitat adequada.
#   * A l’hora d’elaborar el vídeo, tingues en compte que ha de ser entenedor per a qualsevol audiència de nivell universitari (*level 3*). Es recomana veure l’exemple següent:
#     [https://www.youtube.com/watch?v=fkIvmfqX-t0](https://www.youtube.com/watch?v=fkIvmfqX-t0)
#
#
# * **Lliurament del vídeo:**
#
#   * S’ha habilitat una pàgina per al lliurament anomenada **«Entrega de la PAC4 VIDEO»**. Allà heu de pujar un vídeo en **format recomanat mp4** i amb **resolució recomanada de 720p**. El vídeo ha de pesar **menys de 50 MB**.
#   * Podeu gravar-lo amb qualsevol eina que us vagi bé (per exemple, [https://clipchamp.com](https://clipchamp.com)) o bé gravar-lo mitjançant l’eina que hem habilitat en aquesta mateixa pàgina.
#   * Es recomana utilitzar **Chrome**.

# %% [markdown]
# <div style="background-color: #AAF7FF; border-color: #7A9DBF; border-left: 5px solid #7C9DBF; padding: 0.0em;"> <strong>Les referències externes en aquesta PAC han estat citades segons els criteris generals de la norma:
#
# UNE-ISO 690:2013. _Informació i documentació. Directrius per a la redacció de referències bibliogràfiques i de cites de recursos d'informació._
#
# Els criteris generals de citació han estat trobats a:
#
# _Estil ISO 690_ [en línia] [consulta: 29 de desembre de 2025]. Disponible a: [https://biblioteca.uoc.edu:8080/ca/plana/Estil-ISO-690/](https://biblioteca.uoc.edu:8080/ca/plana/Estil-ISO-690/)
# </strong> </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;"> <strong>Exercici 1: Anàlisi preliminar de les dades (1 punt)</strong> </div>
# Com és habitual en aquests casos, comencem realitzant una anàlisi preliminar de les dades. Per a això processarem els conjunts de dades **PROTEINS**, **DD** i **ENZYMES** (proporcionats juntament amb la PAC) i es demana el següent:
#
# * **1.1** Carrega les dades i processa-les adequadament per representar la **Taula 1. *Statistics of benchmark protein-graph-classification datasets*** de l’article
#   [https://iopscience.iop.org/article/10.1088/2632-2153/ad979b#mlstad979bs4](https://iopscience.iop.org/article/10.1088/2632-2153/ad979b#mlstad979bs4).
#   S’ha de mostrar una taula amb un format tan semblant com sigui possible al del *paper*. Fes les suposicions necessàries per determinar si els grafs són dirigits o no dirigits. Si tens dubtes, comenta’ls al fòrum amb els teus companys/es. Si hi ha alguna discrepància, indica-la. *(0,5 punts)*
#
# * **1.2** Fes una breu anàlisi únicament del conjunt de dades **PROTEINS**. Utilitza les mètriques de **grau mitjà** i de **longitud mitjana del camí més curt** per determinar si existeix una diferència significativa entre els grafs etiquetats com a **classe 1** i **classe 2**. Representa els resultats en una o diverses gràfiques. Escriu les teves conclusions en **dues línies**. *(0,5 punts)*

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>El graf és dirigit o no dirigit?</strong>
#
# En comprovar els fitxer de les arestes, s'ha pogut observar que per a una mateixa aresta sempre hi ha el seu invers. És a dir, per cada aresta (u,v) existeix la seva inversa (v,u). A més, ens els fitxers de les arestes no hi ha res que indiqui o doni a entendre que la direcció de les arestes importa.
#
# Donats aquests fets, es suposa que els grafs són no dirigits.
# </div>

# %% [markdown]
# <div style="background-color: #9ECEDD; border-color: #419EBB; border-left: 5px solid #419EBB; padding: 0.5em;">
# <strong>Exercici 1.1</strong>
# </div>

# %% [markdown]
# <div style="background-color: #d2ffc9; border-color: #004000; border-left: 5px solid #004000; padding: 0.5em;">
# <strong>Càrrega fitxers DD</strong>
# </div>

# %%
dd_a = pd.read_table("DD/DD_A.txt", sep=",", header=None) # Bibliografia: [Ref.1] i [Ref.2]
dd_a.rename(columns={0: "Node_id1"}, inplace=True) # Bibliografia: [Ref.3]
dd_a.rename(columns={1: "Node_id2"}, inplace=True) # Bibliografia: [Ref.3]

dd_graph_indicator = pd.read_table("DD/DD_graph_indicator.txt", sep=",", header=None) # Bibliografia: [Ref.1] i [Ref.2]
dd_graph_indicator.rename(columns={0: "Graph_id"}, inplace=True) # Bibliografia: [Ref.3]

dd_graph_labels = pd.read_table("DD/DD_graph_labels.txt", sep=",", header=None) # Bibliografia: [Ref.1] i [Ref.2]
dd_graph_labels.rename(columns={0: "Class_label"}, inplace=True) # Bibliografia: [Ref.3]

dd_node_labels = pd.read_table("DD/DD_node_labels.txt", sep=",", header=None) # Bibliografia: [Ref.1] i [Ref.2]
dd_node_labels.rename(columns={0: "Node_id"}, inplace=True) # Bibliografia: [Ref.3]

# %% [markdown]
# <div style="background-color: #d2ffc9; border-color: #004000; border-left: 5px solid #004000; padding: 0.5em;">
# <strong>Càrrega fitxers ENZYMES</strong>
# </div>

# %%
enzymes_a = pd.read_table("ENZYMES/ENZYMES_A.txt", sep=",", header=None) # Bibliografia: [Ref.1] i [Ref.2]
enzymes_a.rename(columns={0: "Node_id1"}, inplace=True) # Bibliografia: [Ref.3]
enzymes_a.rename(columns={1: "Node_id2"}, inplace=True) # Bibliografia: [Ref.3]

enzymes_graph_indicator = pd.read_table("ENZYMES/ENZYMES_graph_indicator.txt", sep=",", header=None) # Bibliografia: [Ref.1] i [Ref.2]
enzymes_graph_indicator.rename(columns={0: "Graph_id"}, inplace=True) # Bibliografia: [Ref.3]

enzymes_graph_labels = pd.read_table("ENZYMES/ENZYMES_graph_labels.txt", sep=",", header=None) # Bibliografia: [Ref.1] i [Ref.2]
enzymes_graph_labels.rename(columns={0: "Class_label"}, inplace=True) # Bibliografia: [Ref.3]

enzymes_node_attributes = pd.read_table("ENZYMES/ENZYMES_node_attributes.txt", sep=",", header=None) # Bibliografia: [Ref.1] i [Ref.2]

enzymes_node_labels = pd.read_table("ENZYMES/ENZYMES_node_labels.txt", sep=",", header=None) # Bibliografia: [Ref.1] i [Ref.2]
enzymes_node_labels.rename(columns={0: "Node_id"}, inplace=True) # Bibliografia: [Ref.3]

# %% [markdown]
# <div style="background-color: #d2ffc9; border-color: #004000; border-left: 5px solid #004000; padding: 0.5em;">
# <strong>Càrrega fitxers PROTEINS</strong>
# </div>

# %%
proteins_a = pd.read_table("PROTEINS/PROTEINS_A.txt", sep=",", header=None) # Bibliografia: [Ref.1] i [Ref.2]
proteins_a.rename(columns={0: "Node_id1"}, inplace=True) # Bibliografia: [Ref.3]
proteins_a.rename(columns={1: "Node_id2"}, inplace=True) # Bibliografia: [Ref.3]

proteins_graph_indicator = pd.read_table("PROTEINS/PROTEINS_graph_indicator.txt", sep=",", header=None) # Bibliografia: [Ref.1] i [Ref.2]
proteins_graph_indicator.rename(columns={0: "Graph_id"}, inplace=True) # Bibliografia: [Ref.3]

proteins_graph_labels = pd.read_table("PROTEINS/PROTEINS_graph_labels.txt", sep=",", header=None) # Bibliografia: [Ref.1] i [Ref.2]
proteins_graph_labels.rename(columns={0: "Class_label"}, inplace=True) # Bibliografia: [Ref.3]

proteins_node_attributes = pd.read_table("PROTEINS/PROTEINS_node_attributes.txt", sep=",", header=None) # Bibliografia: [Ref.1] i [Ref.2]

proteins_node_labels = pd.read_table("PROTEINS/PROTEINS_node_labels.txt", sep=",", header=None) # Bibliografia: [Ref.1] i [Ref.2]
proteins_node_labels.rename(columns={0: "Node_id"}, inplace=True) # Bibliografia: [Ref.3]

# %% [markdown]
# <div style="background-color: #d2ffc9; border-color: #004000; border-left: 5px solid #004000; padding: 0.5em;">
# <strong>Extracció de dades per la taula</strong>
# </div>

# %%
# -- DD --
num_graphs_dd = dd_graph_labels.shape[0]
num_classes_dd = dd_graph_labels["Class_label"].nunique()
# - Max nodes i mitja -
ids_dd = dd_graph_indicator["Graph_id"].tolist() # Bibliografia: [Ref.4]
dict_graph_nodes_dd = {} # {graph_id: count_nodes}
for id_val in ids_dd:
    if id_val in dict_graph_nodes_dd:
        dict_graph_nodes_dd[id_val] += 1
    else:
        dict_graph_nodes_dd[id_val] = 1
max_nodes_dd = max(dict_graph_nodes_dd.values())
average_nodes_dd = sum(dict_graph_nodes_dd.values()) / len(dict_graph_nodes_dd)
average_edges_dd = (len(dd_a) / num_graphs_dd) / 2 # Dividir per 2 per cada aresta apareix 2 cops

# %%
# -- ENZYMES --
num_graphs_enzymes = enzymes_graph_labels.shape[0]
num_classes_enzymes = enzymes_graph_labels["Class_label"].nunique()
# - Max nodes i mitja -
ids_enzymes = enzymes_graph_indicator["Graph_id"].tolist() # Bibliografia: [Ref.4]
dict_graph_nodes_enzymes = {} # {graph_id: count_nodes}
for id_val in ids_enzymes:
    if id_val in dict_graph_nodes_enzymes:
        dict_graph_nodes_enzymes[id_val] += 1
    else:
        dict_graph_nodes_enzymes[id_val] = 1
max_nodes_enzymes = max(dict_graph_nodes_enzymes.values())
average_nodes_enzymes = sum(dict_graph_nodes_enzymes.values()) / len(dict_graph_nodes_enzymes)
average_edges_enzymes = (len(enzymes_a) / num_graphs_enzymes) / 2 # Dividir per 2 per cada aresta apareix 2 cops

# %%
# -- PROTEINS --
num_graphs_proteins = proteins_graph_labels.shape[0]
num_classes_proteins = proteins_graph_labels["Class_label"].nunique()
# - Max nodes i mitja -
ids_proteins = proteins_graph_indicator["Graph_id"].tolist() # Bibliografia: [Ref.4]
dict_graph_nodes_proteins = {} # {graph_id: count_nodes}
for id_val in ids_proteins:
    if id_val in dict_graph_nodes_proteins:
        dict_graph_nodes_proteins[id_val] += 1
    else:
        dict_graph_nodes_proteins[id_val] = 1
max_nodes_proteins = max(dict_graph_nodes_proteins.values())
average_nodes_proteins = sum(dict_graph_nodes_proteins.values()) / len(dict_graph_nodes_proteins)
average_edges_proteins = (len(proteins_a) / num_graphs_proteins) / 2 # Dividir per 2 per cada aresta apareix 2 cops

# %% [markdown]
# <div style="background-color: #d2ffc9; border-color: #004000; border-left: 5px solid #004000; padding: 0.5em;">
# <strong>Creació i printat de la taula</strong>
# </div>

# %%
# Bibliografia: [Ref.5]
stats = {"Dataset": ["DD", "ENZYMES", "PROTEINS"], "# Grpahs": [num_graphs_dd, num_graphs_enzymes, num_graphs_proteins],
        "# Classes": [num_classes_dd, num_classes_enzymes, num_classes_proteins], "# Nodes": [round(average_nodes_dd, 2),
                                                                                              round(average_nodes_enzymes, 2), 
                                                                                              round(average_nodes_proteins, 2)],
        "# Edges": [round(average_edges_dd, 2), round(average_edges_enzymes, 2), round(average_edges_proteins, 2)], 
         "# Max nodes": [max_nodes_dd, max_nodes_enzymes, max_nodes_proteins]}
df_stats = pd.DataFrame(stats)

# %%
df_stats.style.format({"# Nodes": "{:.2f}", "# Edges": "{:.2f}"}).hide(axis='index') # Bibliografia: [Ref.6] -> Ús 1
# Out:
# <style type="text/css">
# </style>
# <table id="T_9f37f">
#   <thead>
#     <tr>
#       <th id="T_9f37f_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_9f37f_level0_col1" class="col_heading level0 col1" ># Grpahs</th>
#       <th id="T_9f37f_level0_col2" class="col_heading level0 col2" ># Classes</th>
#       <th id="T_9f37f_level0_col3" class="col_heading level0 col3" ># Nodes</th>
#       <th id="T_9f37f_level0_col4" class="col_heading level0 col4" ># Edges</th>
#       <th id="T_9f37f_level0_col5" class="col_heading level0 col5" ># Max nodes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9f37f_row0_col0" class="data row0 col0" >DD</td>
#       <td id="T_9f37f_row0_col1" class="data row0 col1" >1178</td>
#       <td id="T_9f37f_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_9f37f_row0_col3" class="data row0 col3" >284.32</td>
#       <td id="T_9f37f_row0_col4" class="data row0 col4" >715.66</td>
# ...

# %% [markdown]
# <div style="background-color: #9ECEDD; border-color: #419EBB; border-left: 5px solid #419EBB; padding: 0.5em;">
# <strong>Exercici 1.2</strong>
# </div>

# %% [markdown]
# <div style="background-color: #d2ffc9; border-color: #004000; border-left: 5px solid #004000; padding: 0.5em;">
# <strong>Creació de grafs</strong>
# </div>

# %%
graphs = {graph_id: nx.Graph() for graph_id in range(1, num_graphs_proteins + 1)} # +1 perque comencem a crear a aprtir del graf 1 i no del graf 0
graphs_nodes = {} # Bibliografia: [Ref.6] -> Ús 2
# - Afegir nodes a cad graph -
for index, graph_id in proteins_graph_indicator.iterrows(): # Bibliografia: [Ref.7]
    graph = graphs[graph_id.iloc[0]] # Apunt 1
    graph.add_node(index + 1)
    if index + 1 not in graphs_nodes: # Bibliografia: [Ref.6] -> Ús 2
        graphs_nodes[index + 1] = graph_id.iloc[0]
    
# - Afegir arestes -
# Bibliografia: [Ref.6] -> Ús 2
for index, nodes in proteins_a.iterrows():
    node1, node2 = nodes.iloc[0], nodes.iloc[1]
    graph_to_add_edge = graphs_nodes[node1]
    actual_graph = graphs[graph_to_add_edge]
    if not actual_graph.has_edge(node1, node2):
        actual_graph.add_edge(node1, node2)

# %% [markdown]
# **Apunt 1:**
# Si només es posa:
# ```python
# graph_id[0]
# ```
# salta un warning de futur amb el suggeriment de correcció.

# %% [markdown]
# <div style="background-color: #d2ffc9; border-color: #004000; border-left: 5px solid #004000; padding: 0.5em;">
# <strong>Mètriques</strong>
# </div>

# %%
# -- Grau mitjà --
average_degree_dict = {} # {graph_id: average_degree}
for graph_id, graph in graphs.items():
    graph_nodes = graph.number_of_nodes()
    average_degree = sum(dict(graph.degree()).values()) / graph_nodes # Bibliografia: [Ref.8]
    average_degree_dict[graph_id] = average_degree

# %%
# -- longitud mitjana del camí més curt --
avg_shortest_path_length_dict = {} # {graph_id: average_shortest_path_lenght de la component connexa mes gran}
for graph_id, graph in graphs.items():
    # Es calcula la component connexa mes gran com a sistema de seguretat per si el graf sencer no fos connex.
    biggest_connected_component = max(nx.connected_components(graph), key=len) # Bibliografia: [Ref.8]
    subgraph_biggest_connected_component = graph.subgraph(biggest_connected_component) # Bibliografia: [Ref.9]
    avg_shortest_path_length_dict[graph_id] = nx.average_shortest_path_length(subgraph_biggest_connected_component) # Bibliografia: [Ref.10]

# %% [markdown]
# <div style="background-color: #d2ffc9; border-color: #004000; border-left: 5px solid #004000; padding: 0.5em;">
# <strong>Gràfiques</strong>
# </div>

# %%
# -- Mapping de cada grag amb la seva classe --
map_class_graph_id = {} # {graph_id: classe}
for index, graph_class in proteins_graph_labels.iterrows():
    map_class_graph_id[index + 1] = graph_class.iloc[0] # Apunt 1

# -- Saber quins elements de average_degree_dict i avg_shortest_path_length_dict son de cada classe --
average_degree_class1 = []
average_degree_class2 = []
avg_shortest_path_length_class1 = []
avg_shortest_path_length_class2 = []
for graph_id in average_degree_dict.keys():
    if map_class_graph_id[graph_id] == 1:
        average_degree_class1.append(average_degree_dict[graph_id])
        avg_shortest_path_length_class1.append(avg_shortest_path_length_dict[graph_id])
    else:
        average_degree_class2.append(average_degree_dict[graph_id])
        avg_shortest_path_length_class2.append(avg_shortest_path_length_dict[graph_id])

# %% [markdown]
# **Apunt 2:**
#
# En la línia:
# ```python
# plt.boxplot([average_degree_class1, average_degree_class2], labels=["Class 1", "Class 2"])
# ```
# Salta un warning conforme el paràmetre _labels_ ha estat renombrat a _tick_labels_

# %%
# -- Gràfic grau mitjà --
# Bibliografia: [Ref.11]
plt.figure(figsize=(10,10))
plt.boxplot([average_degree_class1, average_degree_class2], tick_labels=["Class 1", "Class 2"]) # Apunt 2 i # Bibliografia: [Ref.12]
plt.title("Grau mitjà per classe", fontsize=20)
plt.ylabel("Grau mitjà", fontsize=15)
plt.tight_layout()
plt.show()

# %%
# -- Gràfic longitud mitjana del camí més curt --
# Bibliografia: [Ref.11]
plt.figure(figsize=(10,10))
plt.boxplot([avg_shortest_path_length_class1, avg_shortest_path_length_class2], tick_labels=["Class 1", "Class 2"]) # Apunt 2 i # Bibliografia: [Ref.12]
plt.title("Longitud mitjana del camí més curt per classe", fontsize=20)
plt.ylabel("Longitud mitjana del camí més curt", fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Conclusions</strong>
#
# La classe 1 té un grau mitjà una superior i camins més llargs amb casos extrems de graus mitjans i camins molt grans i 1 cas de grau mitjà molt petit.
# La classe 2, té un grau mitjà més petit amb casos extrems de graus mitjans molt grans o molt petits. També té camins més curts i valors extrems de camins molt llargs.
#
# </div>

# %% [markdown]
# **Referències externes:**
#
# [Ref.1] -- _How to Read Text Files with Pandas?_ [en línia] [consulta: 29 de desembre de 2025]. Disponible a: [https://www.geeksforgeeks.org/python/how-to-read-text-files-with-pandas/](https://www.geeksforgeeks.org/python/how-to-read-text-files-with-pandas/) **--> Web que explica com llegir fitxers .txt amb Pandas.**
#
# [Ref.2] -- _pandas.read_table_ [en línia] [consulta: 29 de desembre de 2025]. Disponible a: [https://pandas.pydata.org/docs/reference/api/pandas.read_table.html](https://pandas.pydata.org/docs/reference/api/pandas.read_table.html) **--> Documentació oficial de la funció per llefir fitxers generals delimitats.**
#
# [Ref.3] -- _pandas.DataFrame.rename_ [en línia] [consulta: 29 de desembre de 2025]. Disponible a: [https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html) **--> Documentació oficial de la funció per a renombrar.**
#
# [Ref.4] -- _Get Unique Values from a Column in Pandas DataFrame_ [en línia] [consulta: 29 de desembre de 2025]. Disponible a: [https://www.geeksforgeeks.org/python/get-unique-values-from-a-column-in-pandas-dataframe/](https://www.geeksforgeeks.org/python/get-unique-values-from-a-column-in-pandas-dataframe/) **--> Web que explica com obtenir i/o comptar els valors únics d'una columna d'un DataFrame.**
#
# [Ref.5] -- _pandas.DataFrame_ [en línia] [consulta: 29 de desembre de 2025]. Disponible a: [https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html) **--> Documentació oficial de la funció per a crear un dataframe.**
#
# [Ref.6] -- GOOGLE. _Gemini_ [programari]. Versió Gemini 3 Flash. 2025.
#
# **Ús 1 --> S'ha demanat com treure per pantalla un dataframe sense que es vegin els índex (Per fer que la taula s'assembli el més possible a la de l'article) i sense que apareguin 0 extra als decimals**
#
# **Ús 2 --> S'ha demanat a l'eina optimitzar el procès de afegir les arestes ja que la versió inicial era extremadament lenta.**
#
# [Ref.7] -- _How can I iterate over rows in a Pandas DataFrame?_ [en línia] [consulta: 29 de desembre de 2025]. Disponible a: [https://stackoverflow.com/questions/16476924/how-can-i-iterate-over-rows-in-a-pandas-dataframe](https://stackoverflow.com/questions/16476924/how-can-i-iterate-over-rows-in-a-pandas-dataframe) **--> Fil de Stack OVerflow que explica com iterar un dataframe de Pandas**
#
# [Ref.8] -- _Graph.degree_ [en línia] [consulta: 29 de desembre de 2025]. Disponible a: [https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.degree.html#networkx.Graph.degree](https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.degree.html#networkx.Graph.degree) **--> Documentació oficial de la funció per a saber el node d'un grau.**
#
# [Ref.9] -- _Graph.subgraph_ [en línia] [consulta: 29 de desembre de 2025]. Disponible a: [https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.subgraph.html](https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.subgraph.html) **--> Documentació oficial per a crear un subgraf.**
#
# [Ref.10] -- _average_shortest_path_length_ [en línia] [consulta: 29 de desembre de 2025]. Disponible a: [https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.shortest_paths.generic.average_shortest_path_length.html](https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.shortest_paths.generic.average_shortest_path_length.html) **--> Documentació oficial de la funció per a obtenir la longitud mitjana del camí més curt d'un graf.**
#
# [Ref.11] -- _Data Viz Project_ [en línia] [consulta: 29 de desembre de 2025]. Disponible a: [https://datavizproject.com/](https://datavizproject.com/) **--> Web que explica l'ús de diferents tipus de grafics.**
#
# [Ref.12] -- _Box Plot in Python using Matplotlib_ [en línia] [consulta: 29 de desembre de 2025]. Disponible a: [https://www.geeksforgeeks.org/data-visualization/box-plot-in-python-using-matplotlib/](https://www.geeksforgeeks.org/data-visualization/box-plot-in-python-using-matplotlib/) **--> Web que explica com crear un diagrama de caixes amb matplotlib.**
#
# [Ref.] -- __ [en línia] [consulta: 29 de desembre de 2025]. Disponible a: []() **-->**

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;"> <strong>Exercici 2: Graph Attention Network (GAT) (3,5 punts)</strong> </div>
# A partir d’ara, a la PAC, únicament treballarem amb el conjunt de dades **PROTEINS**. Tenint en compte que l’objectiu serà entrenar una xarxa neuronal de grafs per a la classificació de proteïnes, es demana:
#
# * **2.1.** Identifica a l’article com és l’estructura del model **GAT** d’una única capa que proposen i construeix el teu model. Tingues en compte que, a més de la capa GAT, hauràs d’afegir més elements a la teva arquitectura (*dropout*, *fully connected*, etc.). Utilitza les llibreries **PyTorch** i **torch_geometric**. El nombre de paràmetres de la capa GAT ha de ser tal que concordi amb el millor resultat corresponent a la **Figura 6. *Performance comparison with changes in the dimensions of each GNN layer...***. És possible que no tota la informació estigui ben explicada a l’article; assumeix les hipòtesis que consideris i explica-les. Imprimeix i mostra el nombre de paràmetres entrenables de la capa GAT. *(1 punt).*
#
# * **2.2.** Prepara les funcions d’entrenament i els optimitzadors; tria una mètrica de *loss* adequada. Fes un primer *split* de *train/val/test* i realitza un entrenament. Tria el millor *checkpoint* en funció dels resultats del *split* de validació. Finalment, mostra els resultats sobre el *split* de test. Compara els resultats amb els que es mostren a la taula **Taula 2. *Performance comparison of representative GNNs***. Una diferència relativa inferior al 10% és acceptable. Si els teus resultats difereixen més, revisa l’exercici, ajusta la configuració de les capes del model, els hiperparàmetres, etc. Pot ser que et sorgeixin dubtes a l’hora de prendre decisions; comenta’ls al fòrum amb els teus companys/es, etc. *(1 punt).*
#
# * **2.3.** A l’article s’esmenta que utilitzen un **k-fold**. Implementa’l de manera que construeixis els conjunts de dades de *train*, validació i test. En lloc d’un k-fold de 10 com a l’article, utilitza un **k-fold de 5**. Assumeix les hipòtesis que consideris. Ara sí, obtingues resultats per al conjunt de dades **PROTEINS** per al model **GAT** de la **Taula 2. *Performance comparison of representative GNNs***. Representa una taula com la de l’article amb els resultats que tens fins ara. *(1,5 punts)*

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Solució</strong>
# </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;"> <strong>Exercici 3: Graph Sample and Aggregate (GraphSAGE) (2 punts)</strong> </div>
# Ara que tens implementada la teva *pipeline*, modifica-la per construir un model basat en **GraphSAGE**.
#
# * **3.1** De manera similar a l’exercici **2.3**, obtingues resultats per al conjunt de dades **PROTEINS** per al GraphSAGE segons la **Taula 2. *Performance comparison of representative GNNs***. Representa una taula com la de l’article amb els resultats que tens fins ara (**GAT** i **GraphSAGE**).

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Solució</strong>
# </div>

# %% [markdown]
# <div style="background-color: #EDF7FF; border-color: #7C9DBF; border-left: 5px solid #7C9DBF; padding: 0.5em;"> <strong>Exercici 4: Graph Isomorphism Network (GIN) (2 punts)</strong> </div>
#
# * **4.1** De manera similar als exercicis 2.3 i 3, obtingues resultats per al conjunt de dades **PROTEINS** per a l’algorisme GIN segons la **Taula 2. *Performance comparison of representative GNNs***. Representa una taula com la de l’article amb tots els resultats (GAT, GIN i GraphSAGE per al conjunt de dades PROTEINS).

# %% [markdown]
# <div style="background-color: #fcf2f2; border-color: #dfb5b4; border-left: 5px solid #dfb5b4; padding: 0.5em;">
# <strong>Solució</strong>
# </div>
